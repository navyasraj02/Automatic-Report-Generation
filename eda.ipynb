# %% [markdown]
# ## EDA (entry, exit and goal forms)

# %%
import pandas as pd
import numpy as np

# %%
entry_form = pd.read_csv("./data/entry_forms.csv")
goal_form = pd.read_csv("./data/goal_setting.csv")
exit_form = pd.read_csv("./data/exit_forms.csv")

# %% [markdown]
# Entry Form

# %%
# Describe the entry form
entry_form.describe()
# Out:
#                   Timestamp            Email First Name Last Name Experience  \
# count                    24               24         24        24         24
# unique                   24               24         24        24          1
# top     2024-01-10 09:00:00  student1@uh.edu       John       Doe   HON 3397
# freq                      1                1          1         1         24
#
#        Classification             Major         Minor Graduation Date Gender  \
# count              24                24            16              24     24
# unique              3                 8             3               4      2
# top            Junior  Computer Science  Data Science        May 2025   Male
# freq               10                 5            12              10     12
#
#        Ethnicity First Generation International Student
# count         24               24                    24
# unique         5                2                     2
# ...

# %%
# Print the column names with their data types
for col in entry_form.columns:
    print(f"{col}: {entry_form[col].dtype}")
# Out:
# Timestamp: str
# Email: str
# First Name: str
# Last Name: str
# Experience: str
# Classification: str
# Major: str
# Minor: str
# Graduation Date: str
# Gender: str
# Ethnicity: str
# First Generation: str
# International Student: str

# %% [markdown]
# Exit Form

# %%
# Describe the exit form
exit_form.describe()
# Out:
#                   Timestamp            Email Experience Goal 1 Progress  \
# count                    20               20         20              20
# unique                   20               20          1               2
# top     2024-05-10 09:00:00  student1@uh.edu   HON 3397            Lots
# freq                      1                1         20              12
#
#        Goal 2 Progress Goal 3 Progress Goal 1 Connection Goal 2 Connection  \
# count               20              20                20                20
# unique               2               3                 2                 2
# top               Lots            Lots           Largely           Largely
# freq                11              10                15                19
#
#        Goal 3 Connection Teamwork Achieved  ... Recommend Friend Likelihood  \
# count                 20                20  ...                          20
# ...

# %%
# Print the column names with their data types
for col in exit_form.columns:
    print(f"{col}: {exit_form[col].dtype}")
# Out:
# Timestamp: str
# Email: str
# Experience: str
# Goal 1 Progress: str
# Goal 2 Progress: str
# Goal 3 Progress: str
# Goal 1 Connection: str
# Goal 2 Connection: str
# Goal 3 Connection: str
# Teamwork Achieved: str
# Professional Responsibility Achieved: str
# Effective Communication Achieved: str
# Problem Solving Achieved: str
# Cultural Humility Achieved: str
# Ethical Decision Making Achieved: str
# Complete Minor Likelihood: str
# Repeat Experience Likelihood: str
# Pursue Career Likelihood: str
# Recommend Friend Likelihood: str
# Activity Class Discussion: str
# Activity HPE DSI Short Course: str
# Activity Class Presentations: str
# Activity Weekly OneNote: str
# Activity Peer Feedback: str
# Activity Extra Credit: str
# Biggest Lesson Learned: str
# Experience Contribution: str
# Additional Comments: str

# %% [markdown]
# Goal form

# %%
# Describe the goal form
goal_form.describe()
# Out:
#                   Timestamp            Email Experience  \
# count                    20               20         20
# unique                   20               20          1
# top     2024-01-15 09:00:00  student1@uh.edu   HON 3397
# freq                      1                1         20
#
#                               Goal 1                    Goal 2  \
# count                             20                        20
# unique                            20                        20
# top     Improve data analysis skills  Learn Python programming
# freq                               1                         1
#
#                          Goal 3 Teamwork Expected  \
# count                        20                20
# unique                       20                 3
# top     Build portfolio project          Moderate
# freq                          1                 9
#
#        Professional Responsibility Expected Effective Communication Expected  \
# ...

# %%
# Print the column names with their data types
for col in goal_form.columns:
    print(f"{col}: {goal_form[col].dtype}")
# Out:
# Timestamp: str
# Email: str
# Experience: str
# Goal 1: str
# Goal 2: str
# Goal 3: str
# Teamwork Expected: str
# Professional Responsibility Expected: str
# Effective Communication Expected: str
# Problem Solving Expected: str
# Cultural Humility Expected: str
# Ethical Decision Making Expected: str
